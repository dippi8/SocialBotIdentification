# %% [markdown]
# # Create dataset of propaganda_bot and pornbot users

# %%
import time
import tweepy
import pandas as pd
from IPython.display import clear_output
import random

# %%
# create connection with Twitter API

CONSUMER_KEY = 'GeWIh6LTIiPd2mgMh4PhesKkX'
CONSUMER_SECRET = 'BjfHQp3T6XY3esXtYWo7mEh58zUd4v7USruqT1brFTXC0qOUYF'
ACCESS_TOKEN = '973862126216499200-tr3zhK2hOHnnhqegZMviFpoUj3T9nHa'
ACCESS_TOKEN_SECRET = 'LuHRMgpoGT3kjR95z8XPuafllrCaWRHyu86Pdru4zdATD'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %% [markdown]
# ## propaganda

# %%
prop_ids = pd.read_csv('data/propaganda_bots_v3.csv')['0'].tolist()

# %%
prop_ids = list(set(prop_ids))

# %%
user = api.get_user(prop_ids[0])

prop_df = pd.DataFrame([[user.id,
                    user.name,
                    user.screen_name,
                    user.statuses_count,
                    user.followers_count,
                    user.friends_count,
                    user.favourites_count,
                    user.listed_count,
                    user.url,
                    user.lang,
                    user.time_zone,
                    user.location,
                    user.default_profile,
                    user.default_profile_image,
                    user.geo_enabled,
                    user.profile_image_url,
                    #user.profile_banner_url,
                    user.profile_use_background_image,
                    user.profile_background_image_url_https,
                    user.profile_text_color,
                    user.profile_image_url_https,
                    user.profile_sidebar_border_color,
                    user.profile_background_tile,
                    user.profile_sidebar_fill_color,
                    user.profile_background_image_url,
                    user.profile_background_color,
                    user.profile_link_color,
                    user.utc_offset,
                    user.is_translator,
                    user.follow_request_sent,
                    user.protected,
                    user.verified,
                    user.notifications,
                    user.description,
                    user.contributors_enabled,
                    user.following,
                    user.created_at]],
                    columns=["id","name","screen_name","statuses_count","followers_count","friends_count","favourites_count","listed_count","url","lang","time_zone","location","default_profile","default_profile_image","geo_enabled","profile_image_url","profile_use_background_image","profile_background_image_url_https","profile_text_color","profile_image_url_https","profile_sidebar_border_color","profile_background_tile","profile_sidebar_fill_color","profile_background_image_url","profile_background_color","profile_link_color","utc_offset","is_translator","follow_request_sent","protected","verified","notifications","description","contributors_enabled","following","created_at"]
                  )

# %%
i = 0
error_ids_prop = []
error_count = 0

for row in prop_ids[1:]:
    i = i + 1
    try:
        user = api.get_user(row)
        df2 = pd.DataFrame([[user.id,
                            user.name,
                            user.screen_name,
                            user.statuses_count,
                            user.followers_count,
                            user.friends_count,
                            user.favourites_count,
                            user.listed_count,
                            user.url,
                            user.lang,
                            user.time_zone,
                            user.location,
                            user.default_profile,
                            user.default_profile_image,
                            user.geo_enabled,
                            user.profile_image_url,
                            # user.profile_banner_url,
                            user.profile_use_background_image,
                            user.profile_background_image_url_https,
                            user.profile_text_color,
                            user.profile_image_url_https,
                            user.profile_sidebar_border_color,
                            user.profile_background_tile,
                            user.profile_sidebar_fill_color,
                            user.profile_background_image_url,
                            user.profile_background_color,
                            user.profile_link_color,
                            user.utc_offset,
                            user.is_translator,
                            user.follow_request_sent,
                            user.protected,
                            user.verified,
                            user.notifications,
                            user.description,
                            user.contributors_enabled,
                            user.following,
                            user.created_at]],
                            columns=["id","name","screen_name","statuses_count","followers_count","friends_count","favourites_count","listed_count","url","lang","time_zone","location","default_profile","default_profile_image","geo_enabled","profile_image_url","profile_use_background_image","profile_background_image_url_https","profile_text_color","profile_image_url_https","profile_sidebar_border_color","profile_background_tile","profile_sidebar_fill_color","profile_background_image_url","profile_background_color","profile_link_color","utc_offset","is_translator","follow_request_sent","protected","verified","notifications","description","contributors_enabled","following","created_at"]
                          )
        prop_df = prop_df.append(df2, ignore_index=True, verify_integrity=False)
    except:
        error_ids_prop.append(row)
        error_count += 1
        
    clear_output()
    print(str(i) + " / " + str(len(prop_ids)) + '   ---   errors: ' + str(error_count))
    
    if i % 500 == 0:
        print 'sleeping...'
        time.sleep(900)
# Out:
# 3348 / 3349   ---   errors: 37

# %%
prop_df.to_csv('data/propaganda_users.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Porn

# %%
porn_ids = []

for i in range(1,20):
    
    if i < 10:
        index = '0' + str(i)
    else:
        index = str(i)
        
    file = 'data/PornBots/blocklist' + index + '.csv'
    
    porn_ids = porn_ids + pd.read_csv(file)['0'].tolist()

# %%
len(porn_ids)
# Out:
# 83436

# %%
# get 5000 random ids

random.shuffle(porn_ids)
porn_bots = porn_ids[:5000]

# %%
user = api.get_user(porn_bots[0])

porn_df = pd.DataFrame([[user.id,
                    user.name,
                    user.screen_name,
                    user.statuses_count,
                    user.followers_count,
                    user.friends_count,
                    user.favourites_count,
                    user.listed_count,
                    user.url,
                    user.lang,
                    user.time_zone,
                    user.location,
                    user.default_profile,
                    user.default_profile_image,
                    user.geo_enabled,
                    user.profile_image_url,
                    #user.profile_banner_url,
                    user.profile_use_background_image,
                    user.profile_background_image_url_https,
                    user.profile_text_color,
                    user.profile_image_url_https,
                    user.profile_sidebar_border_color,
                    user.profile_background_tile,
                    user.profile_sidebar_fill_color,
                    user.profile_background_image_url,
                    user.profile_background_color,
                    user.profile_link_color,
                    user.utc_offset,
                    user.is_translator,
                    user.follow_request_sent,
                    user.protected,
                    user.verified,
                    user.notifications,
                    user.description,
                    user.contributors_enabled,
                    user.following,
                    user.created_at]],
                    columns=["id","name","screen_name","statuses_count","followers_count","friends_count","favourites_count","listed_count","url","lang","time_zone","location","default_profile","default_profile_image","geo_enabled","profile_image_url","profile_use_background_image","profile_background_image_url_https","profile_text_color","profile_image_url_https","profile_sidebar_border_color","profile_background_tile","profile_sidebar_fill_color","profile_background_image_url","profile_background_color","profile_link_color","utc_offset","is_translator","follow_request_sent","protected","verified","notifications","description","contributors_enabled","following","created_at"]
                  )

# %%
i = 0
error_ids_porn = []
error_count = 0

for row in porn_bots[1:]:
    i = i + 1
    try:
        user = api.get_user(row)
        df2 = pd.DataFrame([[user.id,
                            user.name,
                            user.screen_name,
                            user.statuses_count,
                            user.followers_count,
                            user.friends_count,
                            user.favourites_count,
                            user.listed_count,
                            user.url,
                            user.lang,
                            user.time_zone,
                            user.location,
                            user.default_profile,
                            user.default_profile_image,
                            user.geo_enabled,
                            user.profile_image_url,
                            # user.profile_banner_url,
                            user.profile_use_background_image,
                            user.profile_background_image_url_https,
                            user.profile_text_color,
                            user.profile_image_url_https,
                            user.profile_sidebar_border_color,
                            user.profile_background_tile,
                            user.profile_sidebar_fill_color,
                            user.profile_background_image_url,
                            user.profile_background_color,
                            user.profile_link_color,
                            user.utc_offset,
                            user.is_translator,
                            user.follow_request_sent,
                            user.protected,
                            user.verified,
                            user.notifications,
                            user.description,
                            user.contributors_enabled,
                            user.following,
                            user.created_at]],
                            columns=["id","name","screen_name","statuses_count","followers_count","friends_count","favourites_count","listed_count","url","lang","time_zone","location","default_profile","default_profile_image","geo_enabled","profile_image_url","profile_use_background_image","profile_background_image_url_https","profile_text_color","profile_image_url_https","profile_sidebar_border_color","profile_background_tile","profile_sidebar_fill_color","profile_background_image_url","profile_background_color","profile_link_color","utc_offset","is_translator","follow_request_sent","protected","verified","notifications","description","contributors_enabled","following","created_at"]
                          )
        porn_df = porn_df.append(df2, ignore_index=True, verify_integrity=False)
    except:b
        error_ids_porn.append(row)
        error_count += 1
        
    clear_output()
    print(str(i) + " / " + str(len(porn_bots)) + '   ---   errors: ' + str(error_count))
    
    if i % 500 == 0:
        print 'sleeping...'
        time.sleep(900)
# Out:
# 4999 / 5000   ---   errors: 3581

# %%
porn_bots = porn_ids[5000:15000]

for row in porn_bots:
    i = i + 1
    try:
        user = api.get_user(row)
        df2 = pd.DataFrame([[user.id,
                            user.name,
                            user.screen_name,
                            user.statuses_count,
                            user.followers_count,
                            user.friends_count,
                            user.favourites_count,
                            user.listed_count,
                            user.url,
                            user.lang,
                            user.time_zone,
                            user.location,
                            user.default_profile,
                            user.default_profile_image,
                            user.geo_enabled,
                            user.profile_image_url,
                            # user.profile_banner_url,
                            user.profile_use_background_image,
                            user.profile_background_image_url_https,
                            user.profile_text_color,
                            user.profile_image_url_https,
                            user.profile_sidebar_border_color,
                            user.profile_background_tile,
                            user.profile_sidebar_fill_color,
                            user.profile_background_image_url,
                            user.profile_background_color,
                            user.profile_link_color,
                            user.utc_offset,
                            user.is_translator,
                            user.follow_request_sent,
                            user.protected,
                            user.verified,
                            user.notifications,
                            user.description,
                            user.contributors_enabled,
                            user.following,
                            user.created_at]],
                            columns=["id","name","screen_name","statuses_count","followers_count","friends_count","favourites_count","listed_count","url","lang","time_zone","location","default_profile","default_profile_image","geo_enabled","profile_image_url","profile_use_background_image","profile_background_image_url_https","profile_text_color","profile_image_url_https","profile_sidebar_border_color","profile_background_tile","profile_sidebar_fill_color","profile_background_image_url","profile_background_color","profile_link_color","utc_offset","is_translator","follow_request_sent","protected","verified","notifications","description","contributors_enabled","following","created_at"]
                          )
        porn_df = porn_df.append(df2, ignore_index=True, verify_integrity=False)
    except:
        error_count += 1
        
    clear_output()
    print(str(i) + " / " + str(len(porn_bots)) + '   ---   errors: ' + str(error_count))
    
    if i % 500 == 0:
        print 'sleeping...'
        time.sleep(900)
# 4108          1361388482                 Sara Jeff     vena56028504
# 4109           292732463          Whitney Garrison      anthony1080
#
#       statuses_count  followers_count  friends_count  favourites_count  \
# 0                 80               15            185               381
# 1                 11               29             43                43
# 2                 10                7             74                56
# 3               7372              217            369               491
# 4                 55               10             17               241
# 5                 31                9            130               141
# 6                  1              297           4801                 0
# 7                 47                4            490               173
# 8                 23                8            202               116
# 9                 56                5             31               180
# 10                69               19             52               399
# 11                24               25            209               757
# 12                83               10              4               268
# 13                45               23            219               241
# 14                59                9             56               280
# 15                85               24            160               422
# 16                76               31            194               405
# 17               186               94            212               199
# 18               110               30            168               138
# 19                24               12             19               107
# 20                40               11             56               191
# 21               337               67            648               546
# 22               188               24            158               305
# 23                22                9             15               255
# 24                23                1              5               107
# 25                97               46            367               311
# 26                27                9             98                98
# 27               121               44            350               837
# 28                90               76            355               568
# 29                45               19            973               287
# ...              ...              ...            ...               ...
# 4080              47               15            116               307
# 4081              51               22            185               324
# 4082              39               18            180               211
# 4083             152               23             85               486
# 4084              19                1              6               118
# 4085              41                9             30               193
# 4086              24                9            137               126
# 4087              69               25             36               308
# 4088              27                8             11               103
# 4089              19               19            222               119
# 4090             510                6             74               173
# 4091              20                5             69                93
# 4092              69               60             99               211
# 4093              35               25            314               311
# 4094               1              578           4922                 0
# 4095              89               27            203               255
# 4096              41               61            486               329
# 4097              65                9              0                55
# 4098              27               17            124               321
# 4099              52                6             94               219
# 4100              16               13             64                58
# 4101              40               13            122               140
# 4102             150               20             15               261
# 4103              19                2             21               265
# 4104              73               32            245               120
# 4105              35                5             23               183
# 4106               0                3              6               124
# 4107              65               55            454               459
# 4108               6                3             64                71
# 4109              32               32            327               411
#
#       listed_count                      url   lang         ...          \
# 0                0                     None     en         ...
# 1                1                     None     en         ...
# 2                0                     None     sv         ...
# 3                0                     None     es         ...
# 4                0                     None     en         ...
# 5                0                     None     en         ...
# 6                0  https://t.co/BXBMhKW1pU     en         ...
# 7                0                     None     en         ...
# 8                0                     None     en         ...
# 9                0                     None     en         ...
# 10               0                     None     en         ...
# 11               0                     None     ko         ...
# 12               0                     None     en         ...
# 13               0                     None     en         ...
# 14               0                     None  zh-cn         ...
# 15               0                     None     en         ...
# 16               0  https://t.co/g58sqGMMky     es         ...
# 17               0                     None     de         ...
# 18               0                     None     en         ...
# 19               0                     None     en         ...
# 20               0                     None     en         ...
# 21               0  https://t.co/aLjcoJR64g     en         ...
# 22               0                     None     fr         ...
# 23               0                     None     en         ...
# 24               0                     None     en         ...
# 25               0                     None     es         ...
# 26               0                     None     en         ...
# 27               0   http://t.co/VUSIOUG2nZ     fr         ...
# 28               0                     None     ru         ...
# 29               0                     None     ko         ...
# ...            ...                      ...    ...         ...
# 4080             0                     None     de         ...
# 4081             0                     None     es         ...
# 4082             0                     None     en         ...
# 4083             0                     None     en         ...
# 4084             0                     None     hu         ...
# 4085             0                     None     pl         ...
# 4086             0                     None     pl         ...
# 4087             0                     None     en         ...
