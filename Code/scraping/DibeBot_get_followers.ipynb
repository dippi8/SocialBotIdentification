# %% [markdown]
# # Create dataset of fakefollowers from DibeBot

# %% [markdown]
# ## Get IDs

# %%
import time
import tweepy
import pandas as pd
from IPython.display import clear_output

# %%
# create connection with Twitter API

CONSUMER_KEY = 'GeWIh6LTIiPd2mgMh4PhesKkX'
CONSUMER_SECRET = 'BjfHQp3T6XY3esXtYWo7mEh58zUd4v7USruqT1brFTXC0qOUYF'
ACCESS_TOKEN = '973862126216499200-tr3zhK2hOHnnhqegZMviFpoUj3T9nHa'
ACCESS_TOKEN_SECRET = 'LuHRMgpoGT3kjR95z8XPuafllrCaWRHyu86Pdru4zdATD'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
ids = []

for page in tweepy.Cursor(api.followers_ids, screen_name="DibeBot").pages():
    ids.extend(page)
    time.sleep(60)

print(len(ids))
# Out:
# 224

# %% [markdown]
# ## Extend users and create DF

# %%
user = api.get_user(ids[0])

# %%
df = pd.DataFrame([[user.id,
                    user.name,
                    user.screen_name,
                    user.statuses_count,
                    user.followers_count,
                    user.friends_count,
                    user.favourites_count,
                    user.listed_count,
                    user.url,
                    user.lang,
                    user.time_zone,
                    user.location,
                    user.default_profile,
                    user.default_profile_image,
                    user.geo_enabled,
                    user.profile_image_url,
                    #user.profile_banner_url,
                    user.profile_use_background_image,
                    user.profile_background_image_url_https,
                    user.profile_text_color,
                    user.profile_image_url_https,
                    user.profile_sidebar_border_color,
                    user.profile_background_tile,
                    user.profile_sidebar_fill_color,
                    user.profile_background_image_url,
                    user.profile_background_color,
                    user.profile_link_color,
                    user.utc_offset,
                    user.is_translator,
                    user.follow_request_sent,
                    user.protected,
                    user.verified,
                    user.notifications,
                    user.description,
                    user.contributors_enabled,
                    user.following,
                    user.created_at]],
                    columns=["id","name","screen_name","statuses_count","followers_count","friends_count","favourites_count","listed_count","url","lang","time_zone","location","default_profile","default_profile_image","geo_enabled","profile_image_url","profile_use_background_image","profile_background_image_url_https","profile_text_color","profile_image_url_https","profile_sidebar_border_color","profile_background_tile","profile_sidebar_fill_color","profile_background_image_url","profile_background_color","profile_link_color","utc_offset","is_translator","follow_request_sent","protected","verified","notifications","description","contributors_enabled","following","created_at"]
                  )

# %%
i = 0
for row in ids[1:]:
    i = i + 1
    try:
        user = api.get_user(row)
        df2 = pd.DataFrame([[user.id,
                            user.name,
                            user.screen_name,
                            user.statuses_count,
                            user.followers_count,
                            user.friends_count,
                            user.favourites_count,
                            user.listed_count,
                            user.url,
                            user.lang,
                            user.time_zone,
                            user.location,
                            user.default_profile,
                            user.default_profile_image,
                            user.geo_enabled,
                            user.profile_image_url,
                            # user.profile_banner_url,
                            user.profile_use_background_image,
                            user.profile_background_image_url_https,
                            user.profile_text_color,
                            user.profile_image_url_https,
                            user.profile_sidebar_border_color,
                            user.profile_background_tile,
                            user.profile_sidebar_fill_color,
                            user.profile_background_image_url,
                            user.profile_background_color,
                            user.profile_link_color,
                            user.utc_offset,
                            user.is_translator,
                            user.follow_request_sent,
                            user.protected,
                            user.verified,
                            user.notifications,
                            user.description,
                            user.contributors_enabled,
                            user.following,
                            user.created_at]],
                            columns=["id","name","screen_name","statuses_count","followers_count","friends_count","favourites_count","listed_count","url","lang","time_zone","location","default_profile","default_profile_image","geo_enabled","profile_image_url","profile_use_background_image","profile_background_image_url_https","profile_text_color","profile_image_url_https","profile_sidebar_border_color","profile_background_tile","profile_sidebar_fill_color","profile_background_image_url","profile_background_color","profile_link_color","utc_offset","is_translator","follow_request_sent","protected","verified","notifications","description","contributors_enabled","following","created_at"]
                          )
        df = df.append(df2, ignore_index=True, verify_integrity=False)
    except:
        print("user " + str(row) + " not found")
        
    clear_output()
    print(str(i) + "/" + str(len(ids)))
# Out:
# 223/224

# %%
df
# Out:
#                       id                               name      screen_name  \
# 0             1580182062                             ======   _EddySudarmono
# 1     905649967989121024                     krishna suthar  krishna80216670
# 2    1005031352763236352  HienDu - Boldman Capital Investor        nothehair
# 3    1036099463129980928                        S I SHABBIR       SISHABBIR1
# 4    1020340916832296960                           kimawink      chairsbuddy
# 5    1036292422639206400                              shary    shary01350189
# 6     993745260978171904                          omarfaruk  omarfar77138295
# 7     993411079945375745                         omar Faruk  omarFar10945500
# 8     735516054118649856                           kniheant        tuanahanh
# 9              392415871                  Momo da Depressão  momodadepressao
# 10   1036369332610187266                              COPOO           COPOO5
# 11            4217942747                          PH VÍDEOS  paulolucianaca1
# 12    801707167917211650                     jeanno-shimano   jeanno_shimano
# 13   1032288227527249922                                Ter         kombes90
# 14   1022787642793107456                          abusufyan  abusufy17656544
# 15            3241198300                       Saqib Shaikh     Designfolioo
# 16   1021467170084012032                          ShahidHus       ShahidHus2
# 17    989827348135600128                         Fahadmalik  Fahadma18318257
# 18    902134020099768321                  IV.Fernando Reges  atavratfernando
# 19   1036162328104849410                             saidul   saidul51880621
# 20   1030807158936367105                       rezaoktovian  rezaokt55740875
# 21    993053419282694144                         Tsui Chang          tsui201
# 22   1036135542730108928                         Shipon Roy  ShiponR12672268
# 23   1011324820837920768                         Ssjkgaming       ssjkgaming
# 24   1035797592242716673                         dfcgbjnkdj       dfcgbjnkdj
# 25    924361857934139392                      Only Mobility    onlymobility1
# 26   1031143761391235073                       Manish Kumar  manishkumar_983
# 27    999735986769743872                          Premhasan      Premhasan14
# 28            1932158581                   Egypt channel tv        hggmshady
# 29   1028123163496996864                           bystrick        bystrick2
# ..                   ...                                ...              ...
# 194  1034014777125863424                              mansi    mansi16522113
# 195  1003162622793936896                             du huu           duhuu2
# 196           2937965874                               $ĦĬV   rudrabhatt2702
# 197  1008762962767593472                         Zhang Teng      ZhangTeng11
# 198            302460748                          VashElite          AnonRap
# 199  1019173186552807424                           cubi1501         cubi1501
# 200   887674343441825796                         Vương Khấu        VuongKhau
# 201           2589049951                   Kartell Dubai 🇦🇪     KartellDubai
# 202  1032980435012407296                              usama    usama28234219
# 203  1010037383100710913                              Lucky     milu06180234
# 204  1033672854750081025                        Carlossanto  Carloss66821385
# 205  1027151628258791424                        trunglaca77      trunglaca77
# 206            385485231               Lucia Aurora Freitas  LuciaAuroraFrei
# 207  1033663408996999170                          Xuanxxsgg        xuanxxsgg
# 208  1032846112531443712                         Md Monirul  MdMonir39600368
# 209   971106176166449153                             Dilano   Dilano44210449
# 210  1033921798558035968                             shikha   shikha95189252
# 211  1025235507050102784                        lestad15082      lestad15082
# 212             59653269                              Bruno       brunoxdb13
# 213  1022312751740465152                          Tigreloko       Tigreloko2
# 214  1032842065678200832                           Kevin Xu  KevinXu17209677
# 215  1033591833002221568                           محمد علي    pawlo77293381
# 216  1032179615433814016                                 Li       Li22290639
# 217  1030274018912468992                                Xho      Xho52953119
# 218  1032566056538189831                             basyta          basyta2
# 219  1032317964131811328                              duong    duong08760977
# 220   897137518570688512                            pitusil         pitusil1
# 221  1033017147910316032                             DoTuan   DoTuan93438682
# 222  1029124620539109376                        Irfan Malik  IrfanMa56760370
# 223           1366432777                          DuckPawer        TuTioDuck
#
#      statuses_count  followers_count  friends_count  favourites_count  \
# 0              2458             3361            811               134
# 1                25               70           1963               331
# 2              1371             1819           3001              1649
# 3               201                2            282               152
# 4                 6                2            629                 7
# 5               118                1            639                67
# 6                92                6            573                 1
# 7                50               11            165                32
# 8               967               53            336               756
# 9             10201            22983           3985              3341
# 10                0                0            367                66
# 11              979               47           1198               318
# 12               21               15            484                83
# 13              162               14            903               105
# 14                0               13           1219                 1
# 15               29                1            104                74
# 16              349               18            186                18
# 17                4               16            762                 1
# 18             2268             1385           4081               492
# 19               52                6            840                94
# 20               22               12            841                16
# 21              220               78           1772               420
# 22               74                5            341                51
# 23             4146               33            986              6066
# 24               51                8            559                30
# 25              222              593           1899               127
# 26              130               15           1107                58
# 27               83                4            262                88
# 28              214               10            457                 6
# 29               82                1            574                79
# ..              ...              ...            ...               ...
# 194             140               13            622                65
# 195              26               49           1046                28
# 196            2995              111           3326              1912
# 197             681               45           2012               414
# 198            1465              669           1297               506
# 199             581               38           1796              1298
# 200            3825               69           2603              1555
# 201             778             2618           1476              1379
# 202              67               18            953                48
# 203            4603              111           3418              2696
# 204               0                8            489                81
# 205             572               29           1550               293
# 206               4               16            880               303
# 207              14               10            532                 7
# 208             340                7            404               183
# 209               6               34           1603                62
# 210             121               13            665                55
# 211            1579               35           1674               696
# 212            9044              908           5003              3595
# 213            1698               52           2581              1175
# 214              68               14            728                55
# 215             185                6            842               117
# 216            1268               11           1150               860
# 217             412               18           1264               440
# 218             480               13           1307               395
# 219              38               21           1027               178
# 220             256               12            731               104
# 221              70               15           1188                19
# 222            2549               30           1092              2241
# 223            2596              106           2184              1582
#
#      listed_count                      url   lang         ...          \
# 0               0                     None     id         ...
# 1               0  https://t.co/KABWW8WTh6     en         ...
# 2               0                     None     en         ...
# 3               0                     None     en         ...
# 4               0                     None     en         ...
# 5               0                     None     en         ...
# 6               0                     None     en         ...
# 7               0                     None     en         ...
# 8               1                     None     en         ...
# 9              11                     None     pt         ...
# 10              0                     None     en         ...
# 11              3  https://t.co/cqaum2Ufj1     pt         ...
# 12              0                     None     fr         ...
# 13              0                     None     id         ...
# 14              0                     None     en         ...
# 15              0                     None     en         ...
# 16              0                     None     en         ...
# 17              0                     None  en-gb         ...
# 18              2                     None     tr         ...
# 19              0                     None     en         ...
# 20              0                     None     en         ...
# 21              0                     None     en         ...
# 22              1                     None     en         ...
# 23              1                     None     en         ...
# 24              0                     None     en         ...
# 25              1  https://t.co/USzIRGe3dr     en         ...
# 26              0  https://t.co/nyYaHlPW5K     en         ...
# 27              0                     None     en         ...
# 28              0                     None     ar         ...
# 29              0                     None     en         ...
# ..            ...                      ...    ...         ...
# 194             0                     None     en         ...
# 195             0                     None     en         ...
# 196             0                     None     en         ...
# 197             0  https://t.co/zc2CTKLD0k     en         ...
# 198             9                     None     en         ...
# 199             0                     None     en         ...
# 200             0                     None     vi         ...
# 201            40  https://t.co/Ls9eAaYsrw     fr         ...
# 202             1  https://t.co/yoyhNiQMpS     en         ...
# 203             0                     None     en         ...
# 204             0                     None     en         ...
# 205             1                     None     en         ...
# 206             0                     None     pt         ...
# 207             0                     None     en         ...
# 208             0                     None     en         ...
# 209             0                     None     nl         ...
# 210             0                     None     en         ...
# 211             0                     None     en         ...
# 212             1                     None     en         ...
# 213             0                     None     en         ...
# 214             0                     None     en         ...
# 215             0  https://t.co/r1SgOYg0Yy     en         ...
# 216             0                     None     en         ...
# 217             0                     None     en         ...
# 218             1                     None     en         ...
# 219             0                     None     en         ...
# 220             0                     None     en         ...
# 221             0                     None     en         ...
# 222             2                     None     en         ...
# 223             1  https://t.co/xDxfwBEelh     es         ...
#
#     utc_offset is_translator  follow_request_sent  protected  verified  \
# 0         None         False                False      False     False
# 1         None         False                False      False     False
# 2         None         False                False      False     False
# 3         None         False                False      False     False
# 4         None         False                False      False     False
# 5         None         False                False      False     False
# 6         None         False                False      False     False
# 7         None         False                False      False     False
# 8         None         False                False      False     False
# 9         None         False                False      False     False
# 10        None         False                False      False     False
# 11        None         False                False      False     False
# 12        None         False                False      False     False
# 13        None         False                False      False     False
# 14        None         False                False      False     False
# 15        None         False                False       True     False
# 16        None         False                False      False     False
# 17        None         False                False      False     False
# 18        None         False                False      False     False
# 19        None         False                False      False     False
# 20        None         False                False      False     False
# 21        None         False                False      False     False
# 22        None         False                False      False     False
# 23        None         False                False      False     False
# 24        None         False                False      False     False
# 25        None         False                False      False     False
# 26        None         False                False      False     False
# 27        None         False                False      False     False
# 28        None         False                False      False     False
# 29        None         False                False      False     False
# ..         ...           ...                  ...        ...       ...
# 194       None         False                False      False     False
# 195       None         False                False      False     False
# 196       None         False                False      False     False
# 197       None         False                False      False     False
# 198       None         False                False      False     False
# 199       None         False                False      False     False
# 200       None         False                False      False     False
# 201       None         False                False      False     False
# 202       None         False                False      False     False
# 203       None         False                False      False     False
# 204       None         False                False      False     False
# 205       None         False                False      False     False
# 206       None         False                False      False     False
# 207       None         False                False      False     False
# 208       None         False                False      False     False
# 209       None         False                False      False     False
# 210       None         False                False      False     False
# 211       None         False                False      False     False
# 212       None         False                False      False     False
# 213       None         False                False      False     False
# 214       None         False                False      False     False
# 215       None         False                False      False     False
# 216       None         False                False      False     False
# 217       None         False                False      False     False
# 218       None         False                False      False     False
# 219       None         False                False      False     False
# 220       None         False                False      False     False
# 221       None         False                False      False     False
# 222       None         False                False      False     False
# 223       None         False                False      False     False
#
#     notifications                                        description  \
# 0           False                                 -25 Februari 1993-
# 1           False  #WebDevloper , And #DigitalMarketing #SEO #Soc...
# 2           False  #Crypto #Bitcoin #ICO #bounty #altcoins #bitco...
# 3           False  Hi I Am A Professional Twitter marketer. #twit...
# 4           False
# 5           False
# 6           False                                    I am Omar Faruk
# 7           False                                    I am Omar Faruk
# 8           False
# 9           False
# 10          False
# 11          False  OLÁ  SEJA  BEM VINDO  ao Canal mais Badalado d...
# 12          False                                          good deal
# 13          False                                              Kopat
# 14          False
# 15          False                            Still in progress . . .
# 16          False                              human can't ignore me
# 17          False
# 18          False          En kötü gün bugünse, bugünde Galatasaray!
# 19          False
# 20          False
# 21          False                                      I am a gamer.
# 22          False
# 23          False                                 Hy guys. Greetings
# 24          False
# 25          False  OnlyMobility offers a wide range of power scoo...
# 26          False                                           Youtuber
# 27          False
# 28          False                                        قناة منوعات
# 29          False
# ..            ...                                                ...
# 194         False
# 195         False
# 196         False
# 197         False                                            😃😃😃😃😃😃😃
# 198         False                                              Derp😂
# 199         False
# 200         False
# 201         False  Modern furniture by the world's greatest desig...
# 202         False                                              usama
# 203         False
# 204         False                                 #followback friend
# 205         False
# 206         False
# 207         False
# 208         False
# 209         False
# 210         False
# 211         False
# 212         False
# 213         False
# 214         False  Hello Guys, Subscribe my Yt Chnnel\nTwelve Jan...
# 215         False
# 216         False
# 217         False
# 218         False
# 219         False
# 220         False
# 221         False
# 222         False
# 223         False                               Creador de contenido
#
#     contributors_enabled following          created_at
# 0                  False     False 2013-07-09 12:06:14
# 1                  False     False 2017-09-07 04:32:33
# 2                  False     False 2018-06-08 10:18:41
# 3                  False     False 2018-09-02 03:52:16
# 4                  False     False 2018-07-20 16:13:26
# 5                  False     False 2018-09-02 16:39:01
# 6                  False     False 2018-05-08 06:51:47
# 7                  False     False 2018-05-07 08:43:52
# 8                  False     False 2016-05-25 17:01:07
# 9                  False     False 2011-10-17 00:37:47
# 10                 False     False 2018-09-02 21:44:38
# 11                 False     False 2015-11-18 12:41:43
# 12                 False     False 2016-11-24 08:40:58
# 13                 False     False 2018-08-22 15:27:47
# 14                 False     False 2018-07-27 10:15:51
# 15                 False     False 2015-05-07 22:26:28
# 16                 False     False 2018-07-23 18:48:46
# 17                 False     False 2018-04-27 11:23:24
# 18                 False     False 2017-08-28 11:41:25
# 19                 False     False 2018-09-02 08:02:04
# 20                 False     False 2018-08-18 13:22:32
# 21                 False     False 2018-05-06 09:02:39
# 22                 False     False 2018-09-02 06:15:38
# 23                 False     False 2018-06-25 19:06:41
# 24                 False     False 2018-09-01 07:52:45
# 25                 False     False 2017-10-28 19:46:55
# 26                 False     False 2018-08-19 11:40:05
# 27                 False     False 2018-05-24 19:36:48
# 28                 False     False 2013-10-03 21:33:31
# 29                 False     False 2018-08-11 03:37:18
# ..                   ...       ...                 ...
# 194                False     False 2018-08-27 09:48:28
# 195                False     False 2018-06-03 06:33:01
# 196                False     False 2014-12-21 10:11:34
# 197                False     False 2018-06-18 17:26:47
# 198                False     False 2011-05-21 07:03:08
# 199                False     False 2018-07-17 10:53:17
# 200                False     False 2017-07-19 14:03:50
# 201                False     False 2014-06-26 06:46:10
# 202                False     False 2018-08-24 13:18:22
# 203                False     False 2018-06-22 05:50:52
# 204                False     False 2018-08-26 11:09:48
# 205                False     False 2018-08-08 11:16:46
# 206                False     False 2011-10-05 15:48:41
# 207                False     False 2018-08-26 10:32:16
# 208                False     False 2018-08-24 04:24:37
# 209                False     False 2018-03-06 19:32:09
# 210                False     False 2018-08-27 03:39:00
# 211                False     False 2018-08-03 04:22:47
# 212                False     False 2009-07-24 01:36:35
# 213                False     False 2018-07-26 02:48:48
# 214                False     False 2018-08-24 04:08:32
# 215                False     False 2018-08-26 05:47:50
# 216                False     False 2018-08-22 08:16:12
# 217                False     False 2018-08-17 02:04:02
# 218                False     False 2018-08-23 09:51:46
# 219                False     False 2018-08-22 17:25:57
# 220                False     False 2017-08-14 16:47:07
# 221                False     False 2018-08-24 15:44:15
# 222                False     False 2018-08-13 21:56:44
# 223                False     False 2013-04-20 07:36:29
#
# [224 rows x 36 columns]

# %%
df.to_csv('data/dibeBot_ff.csv',index=False)

# %%
ids = df.id.tolist()

# %%
tweets = []
cont, errors = 0, 0

for user in ids:
    try:
        stuff = api.user_timeline(user_id = user, count = 100, include_rts = True, tweet_mode="extended")
        #tweet.is_quote_status indica se nel tweet c'è il riferimento ad un altro tweet

        for tweet in stuff:
            tweet._json['user_id'] = tweet._json['user']['id']
            if len(tweet._json['entities']['urls']) != 0:
                tweet._json['url'] = tweet._json['entities']['urls'][0]['expanded_url']
            else:
                 tweet._json['url'] = None
            del tweet._json['user'], tweet._json['entities']

            tweets.append(tweet._json)
    except:
        errors += 1
    cont += 1
    clear_output()
    print(str(cont) + ' / 224   ---   errors: ' + str(errors))
    
    if cont % 500 == 0:
        path = 'genuine_tweets_' + str(cont-500) + '-' + str(cont) + '.tw'
        pickle.dump( tweets, open( path , "wb" ) )
        tweets = []
        print ('sleeping...')
        time.sleep(900)
# Out:
# 224 / 224   ---   errors: 2

# %%
df = pd.DataFrame.from_dict(tweets)

# %%
# rimuove tutte le interruzioni (spero)

df['full_text'] = df['full_text'].apply(lambda x: x.replace('\r', ' '))
df['full_text'] = df['full_text'].apply(lambda x: x.replace('\n', ' '))
df['full_text'] = df['full_text'].apply(lambda x: x.replace('\t', ' '))

# %%
df.to_csv('data/dibeBot_ff_tweets.csv', index=False, sep='\t', encoding='utf-8-sig')
