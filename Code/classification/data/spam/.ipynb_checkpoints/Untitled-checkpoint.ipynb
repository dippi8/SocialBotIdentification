# %%
import pandas as pd

# %%
df1 = pd.read_csv('users.csv')

# %%
df2 = pd.read_csv('spam_users2.csv')

# %%
df1 = df1.append(df2, ignore_index=True, verify_integrity=False)

# %%
df1.to_csv('users.csv')

# %%
tw1 = pd.read_csv('tweets.csv', sep='\t', encoding='utf-8-sig')
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,8,18,20,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tw1.head()
# Out:
#    contributors coordinates                      created_at  \
# 0           NaN         NaN  Fri Dec 05 02:19:38 +0000 2014
# 1           NaN         NaN  Fri Dec 05 01:58:53 +0000 2014
# 2           NaN         NaN  Fri Dec 05 01:54:48 +0000 2014
# 3           NaN         NaN  Fri Dec 05 01:42:46 +0000 2014
# 4           NaN         NaN  Fri Dec 05 01:22:32 +0000 2014
#
#   display_text_range extended_entities  favorite_count  favorited  \
# 0            [0, 55]               NaN               2      False
# 1            [0, 57]               NaN               0      False
# 2           [0, 131]               NaN               0      False
# 3            [0, 55]               NaN               0      False
# 4            [0, 59]               NaN               0      False
#
#                                            full_text  geo                  id  \
# 0  Read the History of David Gates  http://t.co/Y...  NaN  540691938639630336
# 1  Caring For Your New Garage Floors  http://t.co...  NaN  540686715145695232
# 2  Check out these awesome baseball t-shirts &amp...  NaN  540685691332857856
# 3  Read the History of Patsy Cline  http://t.co/v...  NaN  540682660352233472
# 4  Great Introduction to Snooky Lanson  http://t....  NaN  540677567481532416
#
#      ...      quoted_status_id quoted_status_id_str  quoted_status_permalink  \
# 0    ...                   NaN                  NaN                      NaN
# 1    ...                   NaN                  NaN                      NaN
# 2    ...                   NaN                  NaN                      NaN
# 3    ...                   NaN                  NaN                      NaN
# 4    ...                   NaN                  NaN                      NaN
#
#    retweet_count  retweeted  retweeted_status  \
# 0              2      False               NaN
# 1              0      False               NaN
# 2              0      False               NaN
# 3              0      False               NaN
# 4              0      False               NaN
#
#                                               source truncated  \
# 0  <a href="http://tweetadder.com" rel="nofollow"...     False
# 1  <a href="http://tweetadder.com" rel="nofollow"...     False
# 2  <a href="http://tweetadder.com" rel="nofollow"...     False
# 3  <a href="http://tweetadder.com" rel="nofollow"...     False
# 4  <a href="http://tweetadder.com" rel="nofollow"...     False
#
#                                                  url    user_id
# 0  http://oldiesmusic.hubpages.com/hub/History-of...  347491211
# 1  http://garage-info.hubpages.com/hub/Caring-For...  347491211
# 2            http://www.cafepress.com/baseballiguide  347491211
# 3  http://oldiesmusic.hubpages.com/hub/History-of...  347491211
# 4  http://oldiesmusic.hubpages.com/hub/Introducti...  347491211
#
# [5 rows x 31 columns]

# %%
tw2 = pd.read_csv('spam_tweets2.csv', sep='\t', encoding='utf-8-sig')
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,8,18,20,23,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tw2.head()
# Out:
#    contributors coordinates                      created_at  \
# 0           NaN         NaN  Tue Sep 08 09:30:10 +0000 2015
# 1           NaN         NaN  Thu Jan 22 14:40:58 +0000 2015
# 2           NaN         NaN  Wed Jan 21 22:44:35 +0000 2015
# 3           NaN         NaN  Wed Jan 21 20:21:18 +0000 2015
# 4           NaN         NaN  Wed Jan 21 20:21:18 +0000 2015
#
#   display_text_range extended_entities  favorite_count  favorited  \
# 0            [0, 89]               NaN               5      False
# 1           [0, 136]               NaN               0      False
# 2           [0, 136]               NaN               0      False
# 3           [0, 136]               NaN               0      False
# 4           [0, 136]               NaN               0      False
#
#                                            full_text  geo                  id  \
# 0  DisneyWorld: The post DisneyWorld appeared fir...  NaN  641181725389754368
# 1  Environmental Impact of Dams: Environmental Im...  NaN  558273119656239104
# 2  Soil Pollution: Soil Pollution Soil pollution ...  NaN  558032439113940992
# 3  Wildlife Conservation: Wildlife Conservation W...  NaN  557996380002611200
# 4  Deforestation: Deforestation Deforestation is ...  NaN  557996379226644480
#
#     ...     quoted_status_id quoted_status_id_str  quoted_status_permalink  \
# 0   ...                  NaN                  NaN                      NaN
# 1   ...                  NaN                  NaN                      NaN
# 2   ...                  NaN                  NaN                      NaN
# 3   ...                  NaN                  NaN                      NaN
# 4   ...                  NaN                  NaN                      NaN
#
#    retweet_count  retweeted  retweeted_status  \
# 0              0      False               NaN
# 1              0      False               NaN
# 2              0      False               NaN
# 3              0      False               NaN
# 4              0      False               NaN
#
#                                               source truncated  \
# 0  <a href="http://twitterfeed.com" rel="nofollow...     False
# 1  <a href="http://twitterfeed.com" rel="nofollow...     False
# 2  <a href="http://twitterfeed.com" rel="nofollow...     False
# 3  <a href="http://twitterfeed.com" rel="nofollow...     False
# 4  <a href="http://twitterfeed.com" rel="nofollow...     False
#
#                      url  user_id
# 0  http://bit.ly/1K4GbzD  7248952
# 1  http://bit.ly/1CjZ25j  7248952
# 2  http://bit.ly/1yK3wzw  7248952
# 3  http://bit.ly/1CQwEGa  7248952
# 4  http://bit.ly/1CQwG0Q  7248952
#
# [5 rows x 31 columns]

# %%
tw1.shape
# Out:
# (362092, 31)

# %%
tw2.shape
# Out:
# (56892, 31)

# %%
tw1 = tw1.append(tw2, ignore_index=True, verify_integrity=False)

# %%
tw1.shape
# Out:
# (418984, 31)

# %%
tw1.to_csv('tweets.csv', sep='\t', encoding='utf-8-sig')
