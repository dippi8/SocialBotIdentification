# %% [markdown]
# # Bot classifier

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.externals import joblib
from sklearn import model_selection, linear_model
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style="white", color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":24,"axes.titlesize":24,"axes.labelsize":24})   

import missingno as msno

# %%
full = pd.read_csv('data/full/train.csv')

# %%
full.columns
# Out:
# Index(['avg_fav', 'avg_hash', 'avg_len', 'avg_ret', 'contributors_enabled',
#        'created_at', 'default_profile', 'default_profile_image', 'description',
#        'fake_words_score', 'favourites_count', 'follow_request_sent',
#        'followers_count', 'following', 'freq', 'friends_count',
#        'genuine_words_score', 'geo_enabled', 'is_translator', 'lang',
#        'listed_count', 'location', 'max_fav', 'max_hash', 'max_len', 'max_ret',
#        'media_perc', 'min_fav', 'min_hash', 'min_len', 'min_ret', 'name',
#        'notifications', 'porn_words_score', 'profile_background_color',
#        'profile_background_image_url', 'profile_background_image_url_https',
#        'profile_background_tile', 'profile_image_url',
#        'profile_image_url_https', 'profile_link_color',
#        'profile_sidebar_border_color', 'profile_sidebar_fill_color',
#        'profile_text_color', 'profile_use_background_image',
#        'prop_words_score', 'protected', 'quote_perc', 'ret_perc',
#        'screen_name', 'spam_words_score', 'statuses_count', 'target',
#        'time_zone', 'tweet_intradistance', 'url', 'url_intradistance',
#        'url_perc', 'user_id', 'utc_offset', 'verified'],
#       dtype='object')

# %% [markdown]
# ## Data exploration

# %%
full.describe()
# Out:
#             avg_fav      avg_hash       avg_len        avg_ret  \
# count  25106.000000  25106.000000  25106.000000   25106.000000
# mean       6.701853      0.187896     56.958004    1480.894377
# std      462.762199      0.486488     52.017380    5434.678244
# min        0.000000      0.000000      0.000000       0.000000
# 25%        0.000000      0.000000      0.000000       0.000000
# 50%        0.000000      0.040000     66.260000       0.040000
# 75%        0.090909      0.200000     91.000000     655.678750
# max    71540.120000     17.000000    308.000000  247147.066667
#
#        contributors_enabled  default_profile  default_profile_image  \
# count               18281.0     22347.000000            18300.00000
# mean                    0.0         0.705956                0.04918
# std                     0.0         0.455622                0.21625
# min                     0.0         0.000000                0.00000
# 25%                     0.0         0.000000                0.00000
# 50%                     0.0         1.000000                0.00000
# 75%                     0.0         1.000000                0.00000
# max                     0.0         1.000000                1.00000
#
#        fake_words_score  favourites_count  follow_request_sent      ...       \
# count      25106.000000      25106.000000              18281.0      ...
# mean           0.023929       5426.449892                  0.0      ...
# std            0.064130      25509.292286                  0.0      ...
# min            0.000000          0.000000                  0.0      ...
# 25%            0.000000          0.000000                  0.0      ...
# 50%            0.013060         70.000000                  0.0      ...
# 75%            0.026143        439.000000                  0.0      ...
# max            1.855191     913239.000000                  0.0      ...
#
#            ret_perc  spam_words_score  statuses_count        target  \
# count  25106.000000      25106.000000    2.510600e+04  25106.000000
# mean       0.233694          0.030912    1.073895e+04      1.877639
# std        0.350675          0.050025    4.146505e+04      1.427447
# min        0.000000          0.000000    0.000000e+00      0.000000
# 25%        0.000000          0.000000    2.100000e+01      0.000000
# 50%        0.000000          0.014325    8.800000e+01      2.000000
# 75%        0.468201          0.043146    2.585000e+03      3.000000
# max        1.000000          0.898990    1.418488e+06      4.000000
#
#        tweet_intradistance  url_intradistance      url_perc       user_id  \
# count         25106.000000       25106.000000  25106.000000  2.510600e+04
# mean              7.452426           1.922121      0.131263  1.637649e+17
# std               6.070453           2.619371      0.233282  3.576332e+17
# min               0.000000           0.000000      0.000000  6.780330e+05
# 25%               0.000000           0.000000      0.000000  3.985294e+08
# 50%              10.614713           0.000000      0.000000  1.355739e+09
# 75%              12.107880           3.394820      0.166667  2.811347e+09
# max              27.574898          10.090432      1.000000  1.036369e+18
#
#          utc_offset      verified
# count   2810.000000  18292.000000
# mean   -4889.145907      0.004702
# std    22037.451204      0.068408
# min   -39600.000000      0.000000
# 25%   -25200.000000      0.000000
# 50%   -14400.000000      0.000000
# 75%    13500.000000      0.000000
# max    46800.000000      1.000000
#
# [8 rows x 44 columns]

# %% [markdown]
# Delete naive features

# %%
full = full.drop(columns=['contributors_enabled', 'follow_request_sent', 'following', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_image_url', 'profile_image_url_https', 'time_zone', 'utc_offset'])

# %% [markdown]
# plot missing values

# %%
features = full.columns

# %%
msno.matrix(full)

# %% [markdown]
# plot missing values for each target

# %%
msno.matrix(full[full.target==0])

# %%
msno.matrix(full[full.target==1])

# %%
msno.matrix(full[full.target==2])

# %%
msno.matrix(full[full.target==3][features[25:]])

# %%
msno.matrix(full[full.target==4][features[25:]])

# %% [markdown]
# Remove features with too many missing values for some target

# %%
full = full.drop(columns=['default_profile_image','is_translator', 'geo_enabled', 'location', 'notifications', 'profile_background_tile', 'protected', 'verified'])

# %%
msno.matrix(full)

# %%
full.default_profile.describe()
# Out:
# count    22347.000000
# mean         0.705956
# std          0.455622
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: default_profile, dtype: float64

# %%
full[full.target==3].default_profile.describe()
# Out:
# count    5995.000000
# mean        0.993328
# std         0.081418
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: default_profile, dtype: float64

# %%
full[full.target==4].default_profile.describe()
# Out:
# count    1219.000000
# mean        0.922888
# std         0.266879
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: default_profile, dtype: float64

# %%
full['default_profile'] = full['default_profile'].fillna(full['default_profile'].mode()[0])

# %%
full['description'] = full['description'].fillna('')

# %%
full['description_len'] = full['description'].apply(lambda x: len(x))

# %%
full = full.drop(columns=['description'])

# %%
full['name'] = full['name'].fillna('')

# %%
full['name_len'] = full['name'].apply(lambda x: len(x))

# %%
full = full.drop(columns=['name'])

# %%
full['screen_name'] = full['screen_name'].fillna('')

# %%
full['screen_name_len'] = full['screen_name'].apply(lambda x: len(x))

# %%
full = full.drop(columns=['screen_name'])

# %%
full = full.drop(columns=['lang'])

# %%
def oldness(x):
    if x[0] == '2':
        return 2018 - int(x[:4])
    else:
        return 2018 - int(x[-4:])

# %%
full['age'] = full['created_at'].apply(lambda x: oldness(x))

# %%
full = full.drop(columns=['created_at'])

# %%
# full = full.drop(columns=['user_id'])

# %%
full['profile_use_background_image'][full.target==4].value_counts()
# Out:
# 1.0    3246
# 0.0      25
# Name: profile_use_background_image, dtype: int64

# %%
full['profile_use_background_image'] = full['profile_use_background_image'].fillna(full['profile_use_background_image'].mode()[0])

# %%
full['url'] = (full['url'].notnull()).astype(int)

# %% [markdown]
# verifico che non ci siano più missing values

# %%
full.isnull().astype(int).sum()
# Out:
# avg_fav                         0
# avg_hash                        0
# avg_len                         0
# avg_ret                         0
# default_profile                 0
# fake_words_score                0
# favourites_count                0
# followers_count                 0
# freq                            0
# friends_count                   0
# genuine_words_score             0
# listed_count                    0
# max_fav                         0
# max_hash                        0
# max_len                         0
# max_ret                         0
# media_perc                      0
# min_fav                         0
# min_hash                        0
# min_len                         0
# min_ret                         0
# porn_words_score                0
# profile_background_color        0
# profile_link_color              0
# profile_sidebar_border_color    0
# profile_sidebar_fill_color      0
# profile_text_color              0
# profile_use_background_image    0
# prop_words_score                0
# quote_perc                      0
# ret_perc                        0
# spam_words_score                0
# statuses_count                  0
# target                          0
# tweet_intradistance             0
# url                             0
# url_intradistance               0
# url_perc                        0
# user_id                         0
# verified                        0
# description_len                 0
# name_len                        0
# screen_name_len                 0
# age                             0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(40,40))
cov=full.corr(method='pearson')
sns.heatmap(cov,annot=True,cmap="Blues",linewidths=.5, ax=ax)

# %%
cov['target'].sort_values(ascending=False)
# Out:
# target                          1.000000
# default_profile                 0.138130
# url                             0.129940
# screen_name_len                 0.125824
# user_id                         0.125303
# profile_use_background_image    0.107442
# avg_ret                         0.095802
# genuine_words_score             0.079692
# max_ret                         0.049879
# description_len                 0.008477
# spam_words_score                0.008449
# min_ret                         0.007841
# fake_words_score               -0.002902
# max_fav                        -0.003242
# min_fav                        -0.004518
# avg_fav                        -0.007160
# followers_count                -0.009184
# verified                       -0.011690
# listed_count                   -0.015293
# statuses_count                 -0.019816
# url_intradistance              -0.037171
# max_len                        -0.037492
# quote_perc                     -0.042583
# friends_count                  -0.044566
# url_perc                       -0.051026
# age                            -0.055187
# favourites_count               -0.077515
# avg_hash                       -0.086026
# freq                           -0.105461
# prop_words_score               -0.107295
# tweet_intradistance            -0.121653
# name_len                       -0.123792
# min_len                        -0.131397
# avg_len                        -0.158282
# max_hash                       -0.185776
# min_hash                       -0.185776
# porn_words_score               -0.264493
# ret_perc                       -0.273895
# media_perc                     -0.293246
# Name: target, dtype: float64

# %%
full.columns
# Out:
# Index(['avg_fav', 'avg_hash', 'avg_len', 'avg_ret', 'default_profile',
#        'fake_words_score', 'favourites_count', 'followers_count', 'freq',
#        'friends_count', 'genuine_words_score', 'listed_count', 'max_fav',
#        'max_hash', 'max_len', 'max_ret', 'media_perc', 'min_fav', 'min_hash',
#        'min_len', 'min_ret', 'porn_words_score', 'profile_background_color',
#        'profile_link_color', 'profile_sidebar_border_color',
#        'profile_sidebar_fill_color', 'profile_text_color',
#        'profile_use_background_image', 'prop_words_score', 'quote_perc',
#        'ret_perc', 'spam_words_score', 'statuses_count', 'target',
#        'tweet_intradistance', 'url', 'url_intradistance', 'url_perc',
#        'user_id', 'verified', 'description_len', 'name_len', 'screen_name_len',
#        'age'],
#       dtype='object')

# %% [markdown]
# # riparti da qui per evitare preprocessing

# %%
full = pd.read_csv('data/full/rf_preproc_train.csv')

# %%
full['context_sum'] = full['porn_words_score'] + full['prop_words_score'] + full['spam_words_score'] + full['fake_words_score'] + full['genuine_words_score']
full['porn_words_score'] = full['porn_words_score'] / full['context_sum']
full['prop_words_score'] = full['prop_words_score'] / full['context_sum']
full['spam_words_score'] = full['spam_words_score'] / full['context_sum']
full['fake_words_score'] = full['fake_words_score'] / full['context_sum']
full['genuine_words_score'] = full['genuine_words_score'] / full['context_sum']

full['porn_words_score'] = full['porn_words_score'].fillna(0.2)
full['prop_words_score'] = full['prop_words_score'].fillna(0.2)
full['spam_words_score'] = full['spam_words_score'].fillna(0.2)
full['fake_words_score'] = full['fake_words_score'].fillna(0.2)
full['genuine_words_score'] = full['genuine_words_score'].fillna(0.2)

# %%
full.iloc[4][['porn_words_score','prop_words_score','spam_words_score','fake_words_score','genuine_words_score']]
# Out:
# porn_words_score       0.349462
# prop_words_score       0.049014
# spam_words_score       0.064234
# fake_words_score       0.087867
# genuine_words_score    0.449424
# Name: 4, dtype: float64

# %%
def predict(X, y, n_trees=5, max_depth=None, knn=10):
    
    forest = RandomForestClassifier(n_estimators = n_trees, max_depth=max_depth, criterion = 'entropy', random_state = 42)
    logreg = linear_model.LogisticRegression()
    
    scaler = MinMaxScaler()
    X_n = scaler.fit_transform(X)
    knn = KNeighborsClassifier(n_neighbors=knn)
    scoring = ['f1_macro', 'precision_macro', 'recall_macro']
    scores = []
    scores.append(cross_validate(forest, X, y, cv=10, scoring=scoring))
    scores.append(cross_validate(logreg, X, y, cv=10, scoring=scoring))
    scores.append(cross_validate(knn, X_n, y, cv=10, scoring=scoring))
    
    return scores

# %%
# only our descriptive features
X = full[['avg_fav', 'avg_hash', 'avg_len', 'avg_ret',
       'freq', 'max_fav', 'max_hash', 'max_len', 'max_ret', 'media_perc', 'min_fav', 'min_hash',
       'min_len', 'min_ret', 'quote_perc',
       'ret_perc', 'url_perc', 'description_len', 'name_len', 'screen_name_len', 'age']]
y = full['target']

# %%
predict(X,y)
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# [{'fit_time': array([0.25922704, 0.24808359, 0.25659847, 0.24352574, 0.25376391,
#          0.25047088, 0.26732469, 0.26206851, 0.25419545, 0.2647624 ]),
#   'score_time': array([0.01073432, 0.01091981, 0.01095986, 0.01116276, 0.01101756,
#          0.01119804, 0.01079702, 0.01102924, 0.01110792, 0.01136041]),
#   'test_f1_macro': array([0.69935523, 0.79615893, 0.88468661, 0.88661043, 0.87099962,
#          0.88269667, 0.85657555, 0.86504063, 0.82613968, 0.71332623]),
#   'train_f1_macro': array([0.97555324, 0.97789827, 0.97602322, 0.97631759, 0.97579883,
#          0.97633842, 0.97708124, 0.97754809, 0.97773533, 0.97920953]),
#   'test_precision_macro': array([0.74042352, 0.83098665, 0.88936005, 0.89947397, 0.87973453,
#          0.88842827, 0.8628439 , 0.87854663, 0.84593042, 0.74078029]),
#   'train_precision_macro': array([0.9770922 , 0.97924491, 0.97744475, 0.97767668, 0.97685671,
#          0.97751062, 0.97775588, 0.97846292, 0.97915795, 0.98057729]),
#   'test_recall_macro': array([0.76228827, 0.80671921, 0.88274773, 0.88316674, 0.87187324,
#          0.87854471, 0.85538611, 0.86175038, 0.82426904, 0.72018104]),
#   'train_recall_macro': array([0.97410845, 0.97666213, 0.9746882 , 0.97504569, 0.97485547,
#          0.97527524, 0.97645192, 0.9767107 , 0.97644295, 0.97796163])},
#  {'fit_time': array([3.09209561, 2.77502871, 3.01682019, 4.16817045, 4.12831926,
#          3.80758166, 3.78937721, 4.4462359 , 3.20516133, 2.7428174 ]),
#   'score_time': array([0.00368714, 0.00365305, 0.00359917, 0.00409532, 0.00379276,
#          0.00359631, 0.00355458, 0.00344181, 0.00363827, 0.00359821]),
#   'test_f1_macro': array([0.50085752, 0.65802827, 0.73547445, 0.69431529, 0.68755184,
#          0.70052154, 0.61144627, 0.52953882, 0.54788771, 0.55851407]),
#   'train_f1_macro': array([0.69038245, 0.67927   , 0.65061375, 0.6674847 , 0.67523408,
#          0.67446874, 0.66352754, 0.67913779, 0.6513114 , 0.69128386]),
#   'test_precision_macro': array([0.51255114, 0.70092053, 0.76265317, 0.72807695, 0.74118481,
#          0.74327056, 0.68318756, 0.63806994, 0.60327672, 0.64898148]),
#   'train_precision_macro': array([0.72556307, 0.70142618, 0.66886842, 0.69760177, 0.70160553,
#          0.70404279, 0.69097887, 0.72839353, 0.68608004, 0.72049409]),
#   'test_recall_macro': array([0.56648885, 0.66413704, 0.73524615, 0.69676085, 0.68582347,
#          0.69782526, 0.6205382 , 0.54505816, 0.57317102, 0.57466   ]),
#   'train_recall_macro': array([0.68712046, 0.67920303, 0.65174464, 0.67005557, 0.67684192,
#          0.6738822 , 0.66485382, 0.68367077, 0.65821048, 0.69360227])},
#  {'fit_time': array([0.33237505, 0.3214426 , 0.31444049, 0.31578875, 0.31761193,
#          0.30184746, 0.16204667, 0.11639905, 0.16005111, 0.11906266]),
#   'score_time': array([1.69273257, 1.56156659, 1.38973331, 1.39660621, 1.40241146,
#          1.27400684, 1.16298389, 1.01821756, 1.15151644, 0.91333556]),
#   'test_f1_macro': array([0.66318082, 0.74968548, 0.85070198, 0.84895314, 0.84821357,
#          0.85222755, 0.71761655, 0.84550362, 0.80955808, 0.67095367]),
#   'train_f1_macro': array([0.86665135, 0.86496815, 0.8581936 , 0.86013076, 0.85749975,
#          0.85821982, 0.86034827, 0.85709011, 0.86188355, 0.870493  ]),
#   'test_precision_macro': array([0.71270777, 0.79297218, 0.87006029, 0.87166955, 0.87197825,
#          0.87255569, 0.77070354, 0.87136303, 0.83940742, 0.72267729]),
#   'train_precision_macro': array([0.88213476, 0.88027749, 0.8723855 , 0.87436827, 0.87182113,
#          0.87293262, 0.8742648 , 0.87114866, 0.87584093, 0.88325837]),
#   'test_recall_macro': array([0.72748936, 0.75762753, 0.84606422, 0.84298092, 0.84066565,
#          0.84350628, 0.72072179, 0.83627903, 0.79915402, 0.68155729]),
#   'train_recall_macro': array([0.85923873, 0.85813917, 0.8515056 , 0.85347087, 0.85103609,
#          0.85134982, 0.85345872, 0.85070096, 0.85519811, 0.86465596])}]

# %%
forest.fit(X,y)
sorted(zip(map(lambda x: round(x, 4), forest.feature_importances_), X.columns), reverse=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-d91bacd80a85> in <module>()
# ----> 1 forest.fit(X,y)
#       2 sorted(zip(map(lambda x: round(x, 4), forest.feature_importances_), X.columns), reverse=True)
#
# NameError: name 'forest' is not defined

# %%
# only context features
X = full[['fake_words_score', 'genuine_words_score', 'porn_words_score', 'prop_words_score', 'spam_words_score']]
y = full['target']

# %%
predict(X,y)

# %%
forest.fit(X,y)
sorted(zip(map(lambda x: round(x, 4), forest.feature_importances_), X.columns), reverse=True)

# %%
# only intradistance features
X = full[['tweet_intradistance', 'url_intradistance']]
y = full['target']

# %%
predict(X,y, n_trees=10, max_depth=None, knn=15)

# %%
forest.fit(X,y)
sorted(zip(map(lambda x: round(x, 4), forest.feature_importances_), X.columns), reverse=True)

# %%
# context + intradistance
X = full[['fake_words_score', 'genuine_words_score', 'porn_words_score', 'prop_words_score', 'spam_words_score', 'tweet_intradistance', 'url_intradistance']]
y = full['target']

# %%
predict(X,y, n_trees=5, max_depth=None, knn=10)

# %%
predict(X,y, n_trees=10, max_depth=None, knn=7)

# %%
forest.fit(X,y)
sorted(zip(map(lambda x: round(x, 4), forest.feature_importances_), X.columns), reverse=True)

# %%
# our features 
X = full[['avg_fav', 'avg_hash', 'avg_len', 'avg_ret',
       'fake_words_score', 'freq',
       'genuine_words_score', 'max_fav',
       'max_hash', 'max_len', 'max_ret', 'media_perc', 'min_fav', 'min_hash',
       'min_len', 'min_ret', 'porn_words_score',
       'prop_words_score', 'quote_perc',
       'ret_perc', 'spam_words_score',
       'tweet_intradistance', 'url', 'url_intradistance', 'url_perc',
       'description_len', 'name_len', 'screen_name_len', 'age']]
y = full['target']

# %%
predict(X,y, n_trees=5, max_depth=None, knn=10)

# %%
predict(X,y, n_trees=10, max_depth=None, knn=8)

# %%
forest.fit(X,y)
sorted(zip(map(lambda x: round(x, 4), forest.feature_importances_), X.columns), reverse=True)

# %%
# only default features
X = full[['default_profile', 'favourites_count', 'followers_count',
       'friends_count', 'listed_count', 'profile_use_background_image', 'statuses_count', 'url', 'verified'
         ]]
y = full['target']

# %%
predict(X,y, n_trees=5, max_depth=None, knn=10)
# Out:
# [0.8679357989410065, 0.5021662998209949, 0.8220401073585675]

# %%
predict(X,y, n_trees=10, max_depth=None, knn=7)
# Out:
# [0.8767512808592951, 0.5021662998209949, 0.8180953337286615]

# %%
forest.fit(X,y)
sorted(zip(map(lambda x: round(x, 4), forest.feature_importances_), X.columns), reverse=True)
# Out:
# [(0.293, 'favourites_count'),
#  (0.2318, 'statuses_count'),
#  (0.1825, 'followers_count'),
#  (0.1195, 'friends_count'),
#  (0.0838, 'default_profile'),
#  (0.0491, 'listed_count'),
#  (0.0358, 'url'),
#  (0.0044, 'profile_use_background_image')]

# %%
# all features except colors
X = full[['avg_fav', 'avg_hash', 'avg_len', 'avg_ret', 'default_profile',
       'fake_words_score', 'favourites_count', 'followers_count', 'freq',
       'friends_count', 'genuine_words_score', 'listed_count', 'max_fav',
       'max_hash', 'max_len', 'max_ret', 'media_perc', 'min_fav', 'min_hash',
       'min_len', 'min_ret', 'porn_words_score',
       'profile_use_background_image', 'prop_words_score', 'quote_perc',
       'ret_perc', 'spam_words_score', 'statuses_count',
       'tweet_intradistance', 'url', 'url_intradistance', 'url_perc',
       'description_len', 'name_len', 'screen_name_len', 'age']]

# %%
y = full['target']

# %%
predict(X,y, n_trees=5, max_depth=None, knn=10)
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# [{'fit_time': array([0.34769511, 0.30481529, 0.31586218, 0.31688499, 0.30595708,
#          0.31996799, 0.3222127 , 0.32402658, 0.31866765, 0.30481601]),
#   'score_time': array([0.00777578, 0.00767851, 0.00813913, 0.00742745, 0.00749516,
#          0.00754786, 0.00765657, 0.0077064 , 0.00776458, 0.00796676]),
#   'test_f1_macro': array([0.83775422, 0.94077931, 0.95758768, 0.95979211, 0.96204971,
#          0.93025025, 0.93115355, 0.93513613, 0.93668537, 0.79112466]),
#   'train_f1_macro': array([0.99407703, 0.99361242, 0.9935447 , 0.99343477, 0.99404944,
#          0.99365356, 0.99361818, 0.99393831, 0.99498684, 0.99545549]),
#   'test_precision_macro': array([0.85580133, 0.94325589, 0.96058536, 0.96309294, 0.96357414,
#          0.93994692, 0.92984083, 0.94030036, 0.93999663, 0.80946545]),
#   'train_precision_macro': array([0.99446709, 0.99412776, 0.994071  , 0.99407208, 0.99432648,
#          0.99404176, 0.99391676, 0.9943478 , 0.99528716, 0.99548683]),
#   'test_recall_macro': array([0.86184928, 0.94038083, 0.9550982 , 0.95752927, 0.96073313,
#          0.92741814, 0.9335374 , 0.93183032, 0.934086  , 0.79606017]),
#   'train_recall_macro': array([0.9936948 , 0.99310701, 0.99302738, 0.99281831, 0.99377898,
#          0.99327866, 0.99332656, 0.9935413 , 0.99469198, 0.99542547])},
#  {'fit_time': array([5.35325933, 4.74363589, 4.94993067, 5.16584754, 5.16624475,
#          5.05709362, 5.37386942, 5.45498085, 5.2437613 , 5.16464281]),
#   'score_time': array([0.00324416, 0.00306416, 0.00300527, 0.00301433, 0.00303149,
#          0.00299954, 0.00298738, 0.00304627, 0.00304747, 0.0031426 ]),
#   'test_f1_macro': array([0.59140265, 0.69622741, 0.75811692, 0.73105518, 0.80198728,
#          0.73275153, 0.63496225, 0.58256003, 0.69129195, 0.62260066]),
#   'train_f1_macro': array([0.72467847, 0.70827441, 0.69934118, 0.68609028, 0.73678909,
#          0.71595157, 0.6688149 , 0.71730318, 0.71257273, 0.73398013]),
#   'test_precision_macro': array([0.71055957, 0.74986239, 0.78835464, 0.76489231, 0.81500715,
#          0.74225597, 0.71314274, 0.6474419 , 0.69404123, 0.65111767]),
#   'train_precision_macro': array([0.76496592, 0.73087714, 0.73034171, 0.72318905, 0.74550443,
#          0.73397213, 0.71181687, 0.73583853, 0.72586116, 0.74760697]),
#   'test_recall_macro': array([0.62345616, 0.70434399, 0.77094465, 0.748743  , 0.80587855,
#          0.74861608, 0.67788379, 0.6049595 , 0.7108228 , 0.64093042]),
#   'train_recall_macro': array([0.74809641, 0.72825316, 0.71857252, 0.70907994, 0.74481492,
#          0.729547  , 0.69615696, 0.7310284 , 0.7258385 , 0.74776021])},
#  {'fit_time': array([0.29692698, 0.28587222, 0.31186485, 0.28627181, 0.29102063,
#          0.3463161 , 0.21614957, 0.17746496, 0.16723561, 0.17750812]),
#   'score_time': array([2.87200737, 2.24788475, 2.2744844 , 2.34726501, 2.81804109,
#          3.08326793, 2.2895956 , 2.38983393, 1.71537066, 1.80454683]),
#   'test_f1_macro': array([0.74017597, 0.83824255, 0.90515197, 0.90026532, 0.89162405,
#          0.89696772, 0.8430644 , 0.84732001, 0.86290349, 0.69240444]),
#   'train_f1_macro': array([0.90451221, 0.90343334, 0.89894583, 0.89953582, 0.89951397,
#          0.89911963, 0.90021177, 0.89923342, 0.90075175, 0.91300604]),
#   'test_precision_macro': array([0.76801689, 0.85968504, 0.91318567, 0.91251719, 0.90831049,
#          0.90718147, 0.85694926, 0.87524351, 0.87920094, 0.72923709]),
#   'train_precision_macro': array([0.91338734, 0.91102046, 0.90701961, 0.90688656, 0.90720837,
#          0.90690223, 0.90754439, 0.90724966, 0.90867205, 0.91812891]),
#   'test_recall_macro': array([0.78786129, 0.83849984, 0.90045454, 0.89295994, 0.88359522,
#          0.88942494, 0.84335236, 0.83898649, 0.85696807, 0.70413236]),
#   'train_recall_macro': array([0.89774682, 0.89767645, 0.89286634, 0.89391747, 0.89362982,
#          0.89317394, 0.89447443, 0.8931188 , 0.89476955, 0.9087692 ])}]

# %%
scores = predict(X,y, n_trees=15, max_depth=None, knn=7)

# %% [markdown]
# ## RF scores:

# %%
print("F1:")
print(scores[0]['test_f1_macro'].mean())
print("Precision:")
print(scores[0]['test_precision_macro'].mean())
print("Recall:")
print(scores[0]['test_recall_macro'].mean())
# Out:
# F1:
# 0.9301791597396043
# Precision:
# 0.9345396345471679
# Recall:
# 0.9328145733187316

# %% [markdown]
# ## KNN scores:

# %%
print("F1:")
print(scores[2]['test_f1_macro'].mean())
print("Precision:")
print(scores[2]['test_precision_macro'].mean())
print("Recall:")
print(scores[2]['test_recall_macro'].mean())
# Out:
# F1:
# 0.8344511371885762
# Precision:
# 0.8550325230230722
# Recall:
# 0.8363502687683884

# %% [markdown]
# ## Grid Search

# %%
def grid_search(X, y, model, params):
    
    scoring = ['f1_macro', 'precision_macro', 'recall_macro']
    grid = GridSearchCV(model, params, cv=10, scoring=scoring, refit='f1_macro')
    grid.fit(X, y)
    
    return grid

# %% [markdown]
# ### KNN

# %%
params = {'n_neighbors':[5,7,10,15,20]}
model = knn = KNeighborsClassifier()
scaler = MinMaxScaler()
X_n = scaler.fit_transform(X)

knn_grid = grid_search(X_n, y, model, params)

# %%
import pandas as pd

# %%
knn_grid.best_params_
# Out:
# {'n_neighbors': 5}

# %%
knn_df = pd.DataFrame(knn_grid.cv_results_)
# Out:
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
knn_df.loc[1]
# Out:
# mean_fit_time                              0.54654
# std_fit_time                                0.2335
# mean_score_time                            3.86909
# std_score_time                             1.05851
# param_n_neighbors                                7
# params                          {'n_neighbors': 7}
# split0_test_f1_macro                      0.729459
# split1_test_f1_macro                      0.816879
# split2_test_f1_macro                      0.901592
# split3_test_f1_macro                      0.890983
# split4_test_f1_macro                      0.885432
# split5_test_f1_macro                       0.89586
# split6_test_f1_macro                      0.799091
# split7_test_f1_macro                      0.861996
# split8_test_f1_macro                      0.855926
# split9_test_f1_macro                      0.693406
# mean_test_f1_macro                        0.833045
# std_test_f1_macro                        0.0691059
# rank_test_f1_macro                               3
# split0_train_f1_macro                     0.908405
# split1_train_f1_macro                     0.905689
# split2_train_f1_macro                     0.899738
# split3_train_f1_macro                     0.901659
# split4_train_f1_macro                     0.901789
# split5_train_f1_macro                     0.900872
# split6_train_f1_macro                       0.9028
# split7_train_f1_macro                     0.902538
# split8_train_f1_macro                     0.902496
# split9_train_f1_macro                     0.913444
# mean_train_f1_macro                       0.903943
#                                        ...
# split7_train_precision_macro              0.909827
# split8_train_precision_macro              0.909875
# split9_train_precision_macro              0.918372
# mean_train_precision_macro                0.911116
# std_train_precision_macro               0.00347934
# split0_test_recall_macro                  0.781005
# split1_test_recall_macro                  0.819595
# split2_test_recall_macro                  0.895403
# split3_test_recall_macro                  0.884773
# split4_test_recall_macro                  0.878845
# split5_test_recall_macro                  0.887123
# split6_test_recall_macro                  0.796783
# split7_test_recall_macro                   0.85223
# split8_test_recall_macro                   0.85072
# split9_test_recall_macro                  0.704556
# mean_test_recall_macro                    0.835095
# std_test_recall_macro                    0.0573875
# rank_test_recall_macro                           2
# split0_train_recall_macro                 0.902524
# split1_train_recall_macro                 0.900449
# split2_train_recall_macro                  0.89432
# split3_train_recall_macro                 0.896489
# split4_train_recall_macro                 0.896332
# split5_train_recall_macro                  0.89577
# split6_train_recall_macro                 0.897533
# split7_train_recall_macro                 0.897263
# split8_train_recall_macro                 0.897203
# split9_train_recall_macro                 0.909636
# mean_train_recall_macro                   0.898752
# std_train_recall_macro                  0.00425669
# Name: 1, Length: 81, dtype: object

# %% [markdown]
# ### Random Forest

# %%
params = {'n_estimators':[15,20,25,30,35,40,45], 'max_depth':[20, 22, 24, 26, 28, 30], 'criterion': ['gini', 'entropy']}
model = RandomForestClassifier()

rf_grid = grid_search(X, y, model, params)

# %%
rf_df = pd.DataFrame(rf_grid.cv_results_)
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
rf_grid.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=28, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=45, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
results = rf_grid.cv_results_

# %%
results['param_criterion'][10:]
# Out:
# masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                    'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                    'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                    'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                    'gini', 'gini', 'gini', 'gini', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object)

# %%
results['mean_test_f1_macro'].max()
# Out:
# 0.9356073402658258

# %%
plt.figure(figsize=(13, 13))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously",
          fontsize=16)

plt.xlabel("n_estimators")
plt.ylabel("Score")
plt.grid()

ax = plt.axes()
ax.set_xlim(7, 57)
ax.set_ylim(0.925, 0.942)

# Get the regular numpy array from the MaskedArray
X_axis = np.array(results['param_n_estimators'].data, dtype=float)

scoring = ['f1_macro', 'precision_macro', 'recall_macro']

for score, color in zip(sorted(scoring), ['b', 'r', 'g']):
    sample_score_mean_gini = results['mean_%s_%s' % ('test', score)][:10]
    sample_score_mean_entropy = results['mean_%s_%s' % ('test', score)][10:]
    crit = results['param_criterion']
    ax.plot(X_axis[:10], sample_score_mean_gini, color=color,
            alpha=1 if sample == 'test' else 0.7,
            linestyle='--',
            label="%s (%s) - %s" % (score, sample, 'gini'))
    ax.plot(X_axis[10:], sample_score_mean_entropy, color=color,
            alpha=1 if sample == 'test' else 0.7,
            label="%s (%s) - %s" % (score, sample, 'entropy'))
 
    best_index = np.nonzero(results['rank_test_' + score] == 1)[0][0]
    best_score = results['mean_test_' + score].max()

    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [0, best_score],
            linestyle='-.', color=color, marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.3f" % best_score,
                (X_axis[best_index]+1, best_score + 0.0005))

plt.legend(loc="best")
plt.grid('off')
plt.show()
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-492c4918c15e> in <module>()
#      21     crit = results['param_criterion']
#      22     ax.plot(X_axis[:10], sample_score_mean_gini, color=color,
# ---> 23             alpha=1 if sample == 'test' else 0.7,
#      24             linestyle='--',
#      25             label="%s (%s) - %s" % (score, sample, 'gini'))
#
# NameError: name 'sample' is not defined

# %% [markdown]
# ### Max depth tuning

# %%
X.columns
# Out:
# Index(['avg_fav', 'avg_hash', 'avg_len', 'avg_ret', 'default_profile',
#        'fake_words_score', 'favourites_count', 'followers_count', 'freq',
#        'friends_count', 'genuine_words_score', 'listed_count', 'max_fav',
#        'max_hash', 'max_len', 'max_ret', 'media_perc', 'min_fav', 'min_hash',
#        'min_len', 'min_ret', 'porn_words_score',
#        'profile_use_background_image', 'prop_words_score', 'quote_perc',
#        'ret_perc', 'spam_words_score', 'statuses_count', 'tweet_intradistance',
#        'url', 'url_intradistance', 'url_perc', 'description_len', 'name_len',
#        'screen_name_len', 'oldness'],
#       dtype='object')

# %%
params = {'n_estimators':[30], 'max_depth':list(range(1,len(X.columns), 3)), 'criterion': ['gini']}
model = RandomForestClassifier()

rf_grid_depth = grid_search(X, y, model, params)
# Out:
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
rf_drig_df = pd.DataFrame(rf_grid_depth.cv_results_)
# Out:
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
rf_grid_depth.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 22, 'n_estimators': 30}

# %%
plt.figure(figsize=(13, 13))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously",
          fontsize=16)

plt.xlabel("max_depth")
plt.ylabel("Score")
plt.grid()

ax = plt.axes()
ax.set_xlim(1, 31)
ax.set_ylim(0.88, 0.96)

# Get the regular numpy array from the MaskedArray
X_axis = np.array(rf_drig_df['param_max_depth'].data, dtype=float)

depth = range(1,len(X.columns), 5)

for d, color in zip(depth, ['k', 'y', 'b', 'r', 'g']):
    sample_score = rf_drig_df['mean_test_f1_macro']
    ax.plot(X_axis, sample_score, color=color,
            alpha=1,
            linestyle='-',
            label="f1_macro_test_%s_depth " % d)
 
    best_index = np.nonzero(rf_drig_df['rank_test_f1_macro'] == 1)[0][0]
    best_score = rf_drig_df['mean_test_f1_macro'].max()

    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [0, best_score],
            linestyle='-.', color=color, marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.3f" % best_score,
                (X_axis[best_index]+1, best_score + 0.0005))

plt.legend(loc="best")
plt.grid('off')
plt.show()
# Out:
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: Series.data is deprecated and will be removed in a future version
#
# /Users/Lorenzo/anaconda/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
params = {'n_estimators':[20,25,30,35,40], 'max_depth':list(range(15,30,3)), 'criterion': ['gini']}
model = RandomForestClassifier()

rf_grid_depth = grid_search(X, y, model, params)

# %%
rf_grid_depth = grid_search(X, y, model, params)

# %%
rf_grid_depth.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 27, 'n_estimators': 40}

# %%
X_axis
# Out:
# array([20., 25., 30., 35., 40., 20., 25., 30., 35., 40., 20., 25., 30.,
#        35., 40., 20., 25., 30., 35., 40., 20., 25., 30., 35., 40.])

# %%
rf_drig_df = pd.DataFrame(results)
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_f1_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_precision_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split5_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split6_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split7_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split8_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split9_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/matteo/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_recall_macro'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
plt.figure(figsize=(13, 13))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously",
          fontsize=16)

plt.xlabel("n_estimators")
plt.ylabel("f1_score")
plt.grid()

ax = plt.axes()
ax.set_xlim(20, 42)
ax.set_ylim(0.926, 0.938)

depth = range(15,30,3)

for d, color in zip(depth, ['k', 'y', 'b', 'r', 'g']):
    # Get the regular numpy array from the MaskedArray
    X_axis = np.array(rf_drig_df[rf_drig_df['param_max_depth'] == d]['param_n_estimators'].data, dtype=float)
    sample_score = rf_drig_df[rf_drig_df['param_max_depth'] == d]['mean_test_f1_macro']
    ax.plot(X_axis, sample_score, color=color,
            linestyle='-',
            label="f1_macro_test_%s_depth " % d)
    

best_index = np.nonzero(rf_drig_df['rank_test_f1_macro'] == 1)[0][0]
best_score = rf_drig_df['mean_test_f1_macro'].max()
X_axis = np.array(rf_drig_df['param_n_estimators'].data, dtype=float)
# Plot a dotted vertical line at the best score for that scorer marked by x
ax.plot([X_axis[best_index], ] * 2, [0, best_score],
        linestyle='-.', color='k', marker='x', markeredgewidth=3, ms=8)

# Annotate the best score for that scorer
ax.annotate("%0.3f" % best_score,
            (X_axis[best_index], best_score + 0.0005))

plt.legend(loc="best")
plt.grid('off')
plt.show()
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/matteo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: Series.data is deprecated and will be removed in a future version
# /home/matteo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: Series.data is deprecated and will be removed in a future version
# /home/matteo/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
model = RandomForestClassifier(n_estimators=30, criterion='gini', max_depth=24)

# %%
model.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=24, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
pickle.dump(model, open("../scripts/rf.model", "wb"))

# %%
model = pickle.load(open("../scripts/rf.model", "rb"))

# %%
forest = model
scoring = ['f1_macro', 'precision_macro', 'recall_macro']
scores = []
scores.append(cross_validate(forest, X, y, cv=10, scoring=scoring))
scores.append(cross_validate(logreg, X, y, cv=10, scoring=scoring))
scores.append(cross_validate(knn, X_n, y, cv=10, scoring=scoring))

# %%
model.
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=24, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
