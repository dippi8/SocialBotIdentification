# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
import re
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
import nltk
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import f1_score
from nltk.corpus import stopwords
import pickle

# %%
users = pd.read_csv('data/full/train.csv')

# %%
users = users[['user_id','target']]

# %%
tweets = pd.concat([pd.read_csv('data/porn/tweets.csv', sep='\t')[['user_id','full_text']], \
          pd.read_csv('data/propaganda/tweets.csv', sep='\t')[['user_id','full_text']], \
          pd.read_csv('data/spam/tweets.csv', sep='\t')[['user_id','full_text']], \
          pd.read_csv('data/fake_followers/tweets.csv', sep='\t')[['user_id','full_text']], \
          pd.read_csv('data/genuine/tweets.csv', sep='\t')[['user_id','full_text']]])
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,8,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/matteo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/matteo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,4,8,11,18,19,20,23,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/matteo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,8,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tweets = tweets.drop_duplicates()

# %%
tweets = pd.merge(tweets, users, on='user_id')

# %%
tweets.drop(['user_id'], axis=1, inplace=True)

# %%
def remove_rt(x):
    if 'RT @' in x:
        try:
            return x[x.find(':')+2:]
        except:
            return x
    else:
        return x

# %%
#def translate(x):
#    try:
#        return translator.translate(x).text
#    except:
#        return x

# %%
stop_words = stopwords.words('english')

def remove_stop(x):
    return [word for word in x.split() if word not in stop_words]

# %%
tweets['full_text'] = tweets['full_text'].apply(lambda x: remove_rt(x))

# %%
tweets['full_text'] = tweets['full_text'].apply(lambda x: re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', x))

# %%
tweets['full_text'] = tweets['full_text'].apply(lambda x: re.sub(r'[^\w\s]','',x))

# %%
tweets['full_text'] = tweets['full_text'].apply(lambda x: x.lower())

# %%
tweets['full_text'] = tweets['full_text'].apply(lambda x: remove_stop(x))

# %%
tweets['full_text'] = tweets['full_text'].astype(str)

# %%
tweets = tweets[tweets.full_text!='[]']

# %%
tweets
# Out:
#                                                  full_text  target
# 1        ['1d', 'stans', 'acting', 'like', '1d', 'super...       0
# 5                    ['hi', 'lets', 'talk', 'look', 'bio']       0
# 6        ['usernames', 'girls', 'live', 'webcam', 'teen...       0
# 7        ['got', 'tattoo', 'last', 'weekend', 'really',...       0
# 8        ['worst', 'year', 'entire', 'life', 'officiall...       0
# 10       ['destined', 'meet', 'meeting', 'sure', 'matte...       0
# 13       ['hi', 'today', 'great', 'day', 'look', 'bio',...       0
# 14       ['whos', 'chopper', 'know', 'bangladesh', 'men...       0
# 15       ['president', 'thomas', 'monson', '16th', 'pro...       0
# 16       ['mr', 'barbaro', 'nytimes', 'ne', 'foolish', ...       0
# 17       ['newsfix', 'mikiebarb', 'thats', 'get', 'mine...       0
# 18       ['oh', 'boy', 'thats', 'moi', 'frozeneastriver...       0
# 19       ['coinbasesupport', 'terrible', 'getting', 'st...       0
# 20       ['kpmgs', 'david', 'ferbrache', 'thoughts', 't...       0
# 21       ['knew', 'heard', '1st', 'snoke', 'porg', 'sta...       0
# 22       ['lo', 'que', 'callamos', 'los', 'youtubers', ...       0
# 23       ['shes', 'stealthvintage', 'fat', 'boy', 'lo',...       0
# 24       ['thing', 'happened', 'delta', 'flight', 'shou...       0
# 25       ['greatest', 'sloth', 'video', 'possibly', 'se...       0
# 26       ['estimada', 'sandy', 'es', 'un', 'gusto', 'sa...       0
# 27       ['los', 'invito', 'seguir', 'la', 'entrevista'...       0
# 28       ['acercarme', 'la', 'gente', 'escucharlos', 'a...       0
# 29       ['envivo', 'conoce', 'a_ahued', 'precandidato'...       0
# 30       ['envivo', 'aspirantes', 'la', 'cdmx', 'entrev...       0
# 31       ['el', 'gobierno', 'puede', 'hacer', 'todo', '...       0
# 32       ['envivo', 'puedo', 'decir', 'que', 'desde', '...       0
# 33       ['envivo', 'desde', 'el_universal_mx', 'sigan'...       0
# 34       ['estamos', 'en', 'un', 'proceso', 'de', 'prec...       0
# 35       ['hay', 'gente', 'que', 'deja', 'de', 'hablar'...       0
# 36       ['tune', 'every', 'friday', 'sat', 'nigezietv'...       0
# ...                                                    ...     ...
# 1233250  ['cant', 'believe', 'already', 'august', 'sure...       4
# 1233251  ['congratulations', 'thomas', 'taylor', 'msd',...       4
# 1233252  ['wishing', 'president', 'lance', 'swank', 'ha...       4
# 1233253  ['moving', 'unfamiliar', 'place', 'summer', 'm...       4
# 1233254  ['employees', 'opinions', 'help', 'us', 'provi...       4
# 1233255  ['crystal', 'branstiters', 'portfolio', '13', ...       4
# 1233256  ['sterling', 'group', 'continues', 'grow', 'tw...       4
# 1233257  ['would', 'like', 'introduce', 'newest', 'memb...       4
# 1233258  ['keep', 'great', 'work', 'wellsleyparkapt', '...       4
# 1233259  ['junes', 'silver', 'star', 'award', 'goes', '...       4
# 1233260  ['cant', 'believe', '258', 'days', 'next', 'st...       4
# 1233261  ['congratulations', 'nancy', 'salmonson', 'bec...       4
# 1233262  ['congratulation', 'michelle', 'schillumeit', ...       4
# 1233263  ['congrats', 'ronnie', 'robertson', 'hampton',...       4
# 1233264  ['aventine', 'wilderness', 'hills', 'beautiful...       4
# 1233265  ['wellsleyparkapt', 'maintenance', 'tech', 'jo...       4
# 1233266  ['dave', 'brogdon', 'maintenance', 'supervisor...       4
# 1233267  ['sterling', 'group', 'hiring', 'jobs', 'knoxv...       4
# 1233268  ['sterling', 'group', 'hiring', 'jobs', 'tulsa...       4
# 1233269  ['retweet', 'help', 'fill', 'job', 'yardi', 's...       4
# 1233270  ['retweet', 'help', 'fill', 'job', 'property',...       4
# 1233271  ['retweet', 'help', 'fill', 'job', 'project', ...       4
# 1233272  ['retweet', 'help', 'fill', 'job', 'leasing', ...       4
# 1233273  ['retweet', 'help', 'fill', 'job', 'leasing', ...       4
# 1233274  ['retweet', 'help', 'fill', 'job', 'general', ...       4
# 1233275  ['retweet', 'help', 'fill', 'job', 'general', ...       4
# 1233276  ['garrathi', 'thanks', 'bringing', 'attention'...       4
# 1233277  ['retweet', 'help', 'fill', 'job', 'property',...       4
# 1233278  ['retweet', 'help', 'fill', 'job', 'assistant'...       4
# 1233279  ['retweet', 'help', 'fill', 'job', 'property',...       4
#
# [1188197 rows x 2 columns]

# %%
stemmer = SnowballStemmer("english", ignore_stopwords=True)

class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(CountVectorizer, self).build_analyzer()
        return lambda doc:(stemmer.stem(w) for w in analyzer(doc))


stem_vectorizer = StemmedCountVectorizer(stemmer)

pipeline = Pipeline([('vect', stem_vectorizer), 
                     ('tfidf', TfidfTransformer()), 
                     ('mnb', MultinomialNB(fit_prior=False))])
X_train, X_test, y_train, y_test = train_test_split(tweets.full_text, tweets.target, test_size=0.33, random_state=42)

clf = pipeline.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('accuracy: ' + str(np.mean(y_pred == y_test)))
print('partial f1: ' + str(f1_score(y_test, y_pred, average=None)))
print('total f1: ' + str(f1_score(y_test, y_pred, average='macro')))
# Out:
# accuracy: 0.7077677974833336
# partial f1: [0.50950804 0.80336242 0.78951357 0.4764248  0.57112931]
# total f1: 0.6299876289362494

# %%
clf.predict_proba(pd.Series("Try this awesome app"))
# Out:
# array([[0.0646053 , 0.07329557, 0.69675381, 0.01342943, 0.15191589]])

# %%
clf = pipeline.fit(tweets.full_text, tweets.target)

# %%
y_pred = clf.predict(tweets.full_text)

print('accuracy: ' + str(np.mean(y_pred == tweets.target)))
print('partial f1: ' + str(f1_score(tweets.target, y_pred, average=None)))
print('total f1: ' + str(f1_score(tweets.target, y_pred, average='macro')))
# Out:
# accuracy: 0.7668795662672099
# partial f1: [0.63853231 0.83060419 0.8263119  0.57269671 0.6802656 ]
# total f1: 0.7096821426189857

# %%
pickle.dump( clf, open( "../scripts/nb.model", "wb" ) )
