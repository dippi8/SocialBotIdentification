# %%
import pandas as pd

# %%
df1 = pd.read_csv('users.csv')

# %%
df2 = pd.read_csv('porn_user2.csv')

# %%
df1.shape
# Out:
# (3798, 36)

# %%
df2 = df2.drop(columns=['Unnamed: 0'])

# %%
df2.shape
# Out:
# (3121, 36)

# %%
df1.head()
# Out:
#            id              name     screen_name  statuses_count  \
# 0   141182021  Elizabeth Little          ns_mia              80
# 1   146443776    Lillian Warren   ihateluvstory              11
# 2  1148187661             Fabbe  FabianAronsson              10
# 3   316622618   Evelyn Garrison      SoSequeira            7372
# 4   405969757     Ella Morrison       ColieDava              55
#
#    followers_count  friends_count  favourites_count  listed_count  url lang  \
# 0               15            185               381             0  NaN   en
# 1               29             43                43             1  NaN   en
# 2                7             74                56             0  NaN   sv
# 3              217            369               491             0  NaN   es
# 4               10             17               241             0  NaN   en
#
#           ...           utc_offset is_translator  follow_request_sent  \
# ...

# %%
df2.head()
# Out:
#                    id               name     screen_name  statuses_count  \
# 0           459406984       Vivian Ogden  Franchistefano              50
# 1  951174706673209344  Florence Oldridge      TheEindier              29
# 2  829398999518105604  Jasmine Eddington       DeFors753               8
# 3           590765863    Adeyemo Adebayo      otunbaboyo             542
# 4          1331142307      Brenda Nelson       ShahirN67             155
#
#    followers_count  friends_count  favourites_count  listed_count  url lang  \
# 0               21            142               159             0  NaN   it
# 1               15            271               142             0  NaN   nl
# 2                9              2               151             0  NaN   ru
# 3              142            659               746             0  NaN   en
# 4               29             13               299             0  NaN   en
#
# ...

# %%
df1 = df1.append(df2, ignore_index=True, verify_integrity=False)

# %%
df1.to_csv('users.csv')

# %%
tw1 = pd.read_csv('tweets.csv', sep='\t', encoding='utf-8-sig')
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (31,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tw1.head()
# Out:
#    contributors coordinates                      created_at  \
# 0           NaN         NaN  Sat Jan 06 10:03:06 +0000 2018
# 1           NaN         NaN  Fri Jan 05 09:38:26 +0000 2018
# 2           NaN         NaN  Fri Jan 05 08:26:24 +0000 2018
# 3           NaN         NaN  Fri Jan 05 08:25:41 +0000 2018
# 4           NaN         NaN  Fri Jan 05 08:23:16 +0000 2018
#
#   display_text_range                                  extended_entities  \
# 0             [0, 0]  {u'media': [{u'expanded_url': u'https://twitte...
# 1           [0, 140]                                                NaN
# 2             [0, 0]  {u'media': [{u'expanded_url': u'https://twitte...
# 3             [0, 0]  {u'media': [{u'expanded_url': u'https://twitte...
# 4             [0, 0]  {u'media': [{u'expanded_url': u'https://twitte...
#
#    favorite_count  favorited  \
# 0               2      False
# 1               0      False
# 2               0      False
# 3               0      False
# ...

# %%
tw2 = pd.read_csv('porn_tweets2.csv', sep='\t', encoding='utf-8-sig')

# %%
tw2.head()
# Out:
#    contributors  coordinates                      created_at  \
# 0           NaN          NaN  Tue Feb 20 17:49:53 +0000 2018
# 1           NaN          NaN  Tue Feb 20 17:49:14 +0000 2018
# 2           NaN          NaN  Tue Feb 20 17:44:13 +0000 2018
# 3           NaN          NaN  Tue Feb 20 17:40:42 +0000 2018
# 4           NaN          NaN  Tue Feb 20 17:34:24 +0000 2018
#
#   display_text_range                                  extended_entities  \
# 0           [0, 123]  {'media': [{'id': 964970591597015041, 'id_str'...
# 1           [0, 140]                                                NaN
# 2            [0, 46]  {'media': [{'id': 905953503943778304, 'id_str'...
# 3            [0, 60]  {'media': [{'id': 963801057758343173, 'id_str'...
# 4            [0, 57]                                                NaN
#
#    favorite_count  favorited  \
# 0               0      False
# 1               0      False
# 2               0      False
# 3               0      False
# ...

# %%
tw1.shape
# Out:
# (191567, 34)

# %%
tw2.shape
# Out:
# (5385, 32)

# %%
tw1 = tw1.drop(columns=['withheld_copyright', 'withheld_in_countries', 'withheld_scope'])

# %%
tw1.shape
# Out:
# (191567, 31)

# %%
tw2 = tw2.drop(columns=['withheld_in_countries'])

# %%
tw2.shape
# Out:
# (5385, 31)

# %%
tw1 = tw1.append(tw2, ignore_index=True, verify_integrity=False)

# %%
tw1.shape
# Out:
# (196952, 31)

# %%
tw1.to_csv('tweets.csv', sep='\t', encoding='utf-8-sig')
