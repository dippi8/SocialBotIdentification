# %%
import debot
import time
import tweepy
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-ea26ef75504b> in <module>()
# ----> 1 import debot
#       2 import time
#       3 import tweepy
#       4 import pandas as pd
#
# ImportError: No module named debot

# %%
db = debot.DeBot('HAI67R5rXgW7G4WhAl5kX8LYciMMI2Xfsubpc7H0')

# %%
# sembra dare molte notizie politiche

db.get_related_bots('news')
# Out:
# '<?xml version="1.0"?>\n<response status="success">\n <topic title="#2017FakeNewsPredictions">\n  <user>\n   <id></id>\n   <screen_name>nana5greatgrand</screen_name>\n   <date>2017-01-04</date>\n  </user>\n </topic>\n <topic title="#3DaysUntilSelenasNewSingle">\n  <user>\n   <id>118709067</id>\n   <screen_name>GuiCoradelli</screen_name>\n   <date>2017-07-10</date>\n  </user>\n </topic>\n <topic title="#AajKaGoodNews">\n  <user>\n   <id></id>\n   <screen_name>trendinaliaIN</screen_name>\n   <date>2016-09-11</date>\n  </user>\n </topic>\n <topic title="#C4News">\n  <user>\n   <id>1266803563</id>\n   <screen_name>trendinaliaGB</screen_name>\n   <date>2017-04-18</date>\n  </user>\n </topic>\n <topic title="#GoodNewsIn5Words">\n  <user>\n   <id>316075542</id>\n   <screen_name>naturallytns</screen_name>\n   <date>2017-03-15</date>\n  </user>\n  <user>\n   <id>756764540</id>\n   <screen_name>fcbfi_cirebon</screen_name>\n   <date>2017-03-15</date>\n  </user>\n  <user>\n   <id>3499636752</id>
# ...

# %%
# 

# sembra dare molte notizie politiche

db.get_related_bots('adult')
# Out:
# '<?xml version="1.0"?>\n<response status="success">\n <topic title="#AdultFilmAMovieOrTvShow">\n  <user>\n   <id></id>\n   <screen_name>QatarL143</screen_name>\n   <date>2016-11-05</date>\n  </user>\n  <user>\n   <id></id>\n   <screen_name>TrendTopicsLa</screen_name>\n   <date>2016-11-05</date>\n  </user>\n </topic>\n <topic title="#AdultingIn5Words">\n  <user>\n   <id>825488341197942784</id>\n   <screen_name>Vmbritsch</screen_name>\n   <date>2017-06-21</date>\n  </user>\n  <user>\n   <id>820879476435419137</id>\n   <screen_name>LuxyWrist</screen_name>\n   <date>2017-06-21</date>\n  </user>\n  <user>\n   <id>789671472927309824</id>\n   <screen_name>skizz0phrenia</screen_name>\n   <date>2017-06-21</date>\n  </user>\n  <user>\n   <id>2435265057</id>\n   <screen_name>LarrySwiftie</screen_name>\n   <date>2017-06-21</date>\n  </user>\n  <user>\n   <id>1002208933</id>\n   <screen_name>esra_mermer</screen_name>\n   <date>2017-06-21</date>\n  </user>\n  <user>\n   <id>835540964215226372</id>
# ...
